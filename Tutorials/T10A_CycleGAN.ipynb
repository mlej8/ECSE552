# %% [markdown]
# <a href="https://colab.research.google.com/github/mlej8/ECSE552/blob/main/Tutorials/T10A_CycleGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Style Transfer with CycleGAN
#
# Remember those filters where you can transform your appearance from masculine to feminine and vice versa?
# We are going to do something similar but a bit simpler. This task is called, style transfer or image-to-image translation.
#
# Applications:
# - entertainment
# - robot adaptation from simulation to reality
# - data augmentation
#
# In this tutorial, we will be implementing [CycleGAN](https://arxiv.org/pdf/1703.10593.pdf), which became extremely popular when it was published. Some portions of the code were directly lifted from the simplified implementation in https://github.com/yunjey/mnist-svhn-transfer

# %% [markdown]
# # Dataset Preparation

# %%
import torch
import torchvision
from torchvision import datasets
from torchvision import transforms
import numpy as np
import random
import os

batch_size=64

transform = transforms.Compose([
                transforms.Resize(32),
                transforms.ToTensor(),])

#os.mkdir('data')

svhn = datasets.SVHN(root='data/', download=True, transform=transform)
mnist = datasets.MNIST(root='data/', download=True, transform=transform)

svhn_loader = torch.utils.data.DataLoader(dataset=svhn,
                                          batch_size=batch_size,
                                          shuffle=True,
                                          num_workers=2)

mnist_loader = torch.utils.data.DataLoader(dataset=mnist,
                                           batch_size=batch_size,
                                           shuffle=True,
                                           num_workers=2)
# Out:
# Using downloaded and verified file: data/train_32x32.mat

# %%
SEED=2
torch.manual_seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %% [markdown]
# Let us look at some of the samples in the dataset

# %%
import matplotlib.pyplot as plt

dataiter = iter(svhn_loader)
images, labels = dataiter.next()
img = images[:8]
img = torchvision.utils.make_grid(img) # this just compiles our data in a single image
npimg = img.numpy()
plt.imshow(np.transpose(npimg, (1, 2, 0))) # channel dimension is last
plt.show()

# %%
dataiter = iter(mnist_loader)
images, labels = dataiter.next()
img = images[:8]
img = torchvision.utils.make_grid(img) # this just compiles our data in a single image
npimg = img.numpy()
plt.imshow(np.transpose(npimg, (1, 2, 0))) # channel dimension is last
plt.show()

# %% [markdown]
# So our task is to make the "clean" MNIST samples look like a "real" image make the "noisy" SVHN samples like MNIST.
#
#
# # CycleGAN Network Components
#
# First, we need to define the architecture. Our CycleGAN is composed of 4 components:
# - MNIST to SVHN transformer
# - SVHN to MNIST transformer
# - MNIST discriminator
# - SVHN discriminator

# %% [markdown]
# ![Screenshot from 2021-03-30 20-16-26.png](data:image/png;base64,...)

# %%
import torch.nn as nn
import torch.nn.functional as F

class Generator(nn.Module):
    def __init__(self, in_channels=3, out_channels=1, conv_dim=64):
        super(Generator, self).__init__()
        # encoder
        self.conv1 = nn.Conv2d(in_channels, conv_dim, 4, 2, 1)
        self.bn1 = nn.BatchNorm2d(conv_dim)
        self.conv2 = nn.Conv2d(conv_dim, conv_dim*2, 4, 2, 1)
        self.bn2 = nn.BatchNorm2d(conv_dim*2)
        self.conv3 = nn.Conv2d(conv_dim*2, conv_dim*2, 3, 1, 1)
        self.bn3 = nn.BatchNorm2d(conv_dim*2)
        self.conv4 = nn.Conv2d(conv_dim*2, conv_dim*2, 3, 1, 1)
        self.bn4 = nn.BatchNorm2d(conv_dim*2)
        
        # decoder
        self.deconv1 = nn.ConvTranspose2d(conv_dim*2, conv_dim, 4, 2, 1)
        self.bn5 = nn.BatchNorm2d(conv_dim)
        self.deconv2 = nn.ConvTranspose2d(conv_dim, out_channels, 4, 2, 1)
        
    def forward(self, x):
        out = F.leaky_relu(self.conv1(x))      # (-1, 64, 16, 16)
        out = self.bn1(out)
        out = F.leaky_relu(self.conv2(out))    # (-1, 128, 8, 8)
        out = self.bn2(out)
        out = F.leaky_relu(self.conv3(out))    # (-1, 128, 8, 8)
        out = self.bn3(out)
        out = F.leaky_relu(self.conv4(out))    # (-1, 128, 8, 8)
        out = self.bn4(out)
        
        out = F.leaky_relu(self.deconv1(out))  # (-1, 64, 16, 16)
        out = self.bn5(out)
        out = torch.relu(self.deconv2(out))    # (-1, 3, 32, 32)
        return out


class Discriminator(nn.Module):
    def __init__(self, in_channels=3, conv_dim=64):
        super(Discriminator, self).__init__()
        self.conv1 = nn.Conv2d(in_channels, conv_dim, 4, 2, 1)
        self.conv2 = nn.Conv2d(conv_dim, conv_dim*2, 4, 2, 1)
        self.conv3 = nn.Conv2d(conv_dim*2, conv_dim*2, 4, 2, 1)
        self.disc_out = nn.Conv2d(conv_dim*2, 1, 4, 1, 0)
        
    def forward(self, x):
        out = F.leaky_relu(self.conv1(x))    # (-1, 64, 16, 16)
        out = F.leaky_relu(self.conv2(out))  # (-1, 128, 8, 8)
        out = F.leaky_relu(self.conv3(out))  # (-1, 256, 4, 4)
        out = self.disc_out(out).squeeze()
        return out

# %% [markdown]
# Let's initialize the network and define the optimizers. Take note that we have 2 optimizers with mutually exclusive set of parameters to optimize.

# %%
from torch import optim
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

m2s = Generator(in_channels=1, out_channels=3).to(device)
s2m = Generator(in_channels=3, out_channels=1).to(device)
dm = Discriminator(in_channels=1).to(device)
ds = Discriminator(in_channels=3).to(device)
        
g_params = list(m2s.parameters()) + list(s2m.parameters())
d_params = list(dm.parameters()) + list(ds.parameters())
        
g_optimizer = optim.Adam(g_params, 1e-4, [0.5,0.999])
d_optimizer = optim.Adam(d_params, 2e-4, [0.5,0.999])

# %% [markdown]
# The idea of CycleGAN is that the image is well-translated if:
# - the transformed image can confuse the discriminator and
# - the transformed image can be translated back to its own style with minimal reconstruction error
#
# The first criterion can be done by adversarial training (it is a GAN after all). The second one can be achieved using a cycle consistency loss.
#
# In addition, you may include other losses for classification/regresson if your dataset has labels. This allows a better "anchor" on the dataset.
#
# ## Training the discriminator
#
# We have two discriminators, one for SVHN and another for MNIST. The goal of these discriminators are to detect if the image is real or fake/translated.
#
# Although it is more intuitive to use a binary cross entropy loss, we will define the discriminator loss as the MSE. According to the paper, this loss function is more stable.

# %%
def discriminator_loss(pred_dm, pred_ds, real_image):
    return torch.mean((pred_dm-real_image)**2) + torch.mean((pred_ds-real_image)**2)

def train_discriminator(svhn, mnist):
    dm.train()
    ds.train()
    s2m.train()
    m2s.train()
    
    g_optimizer.zero_grad()
    d_optimizer.zero_grad()

    fake_mnist = s2m(svhn)
    fake_svhn = m2s(mnist)
    
    mnist_ = torch.cat([mnist, fake_mnist], axis=0)
    svhn_ = torch.cat([svhn, fake_svhn], axis=0)
    
    pred_m = dm(mnist_)
    pred_s = ds(svhn_)
    d_real_loss = discriminator_loss(pred_m[:batch_size], pred_s[:batch_size], 1) # first half are real images
    d_fake_loss = discriminator_loss(pred_m[batch_size:], pred_s[batch_size:], 0) # second half are fake ones

    d_loss = d_real_loss + d_fake_loss
    d_loss.backward()
    d_optimizer.step()
    
    return d_real_loss, d_fake_loss

# %% [markdown]
# ## Training the Generator
#
#
# Training the generator is a bit more complex because it has to satisfy the two criteria above. First, the generator must be able to transform the samples such that the discriminator would classify it as real. Since we used MSE for the discriminator, we will also use MSE for the generator.
#
# ***Note:*** We will only take into account the fake images
#
# Second, the complementary generator must be able to reverse the transformation process. You can think of it as similar to an autoencoder but there is no dimensionality reduction.

# %% [markdown]
# ![Screenshot from 2021-03-30 20-17-51.png](data:image/png;base64,...)

# %%
def train_generator(svhn, mnist):
    dm.train()
    ds.train()
    s2m.train()
    m2s.train()
    
    g_optimizer.zero_grad()
    d_optimizer.zero_grad()
    
    fake_svhn = m2s(mnist)
    out = ds(fake_svhn)
    reconst_mnist = s2m(fake_svhn)
    
    mnist_g_loss = torch.mean((out-1)**2) # MSE 
    mnist_recons_loss = torch.mean((mnist - reconst_mnist)**2)
     
    fake_mnist = s2m(svhn)
    out = dm(fake_mnist)
    reconst_svhn = m2s(fake_mnist)
    svhn_g_loss = torch.mean((out-1)**2) # MSE
    svhn_recons_loss = torch.mean((svhn - reconst_svhn)**2)

    g_loss = mnist_g_loss + mnist_recons_loss + svhn_g_loss + svhn_recons_loss
    g_loss.backward()
    g_optimizer.step()
    
    return g_loss

# %% [markdown]
# ## Finally, we can define our training loop

# %%
#os.mkdir('samples')

# %%
def train(svhn_loader, mnist_loader, train_iters):
    svhn_iter = iter(svhn_loader)
    mnist_iter = iter(mnist_loader)
    iter_per_epoch = min(len(svhn_iter), len(mnist_iter))

    # Select some random samples for visual validation since we do not have a test set
    fixed_svhn = svhn_iter.next()[0].to(device)
    fixed_mnist = mnist_iter.next()[0].to(device)


    for step in range(train_iters+1):

        # reset data_iter for each epoch
        if (step+1) % iter_per_epoch == 0:
            mnist_iter = iter(mnist_loader)
            svhn_iter = iter(svhn_loader)

        # load svhn and mnist dataset
        svhn, s_labels = svhn_iter.next() 
        svhn = svhn.to(device)
        mnist, m_labels = mnist_iter.next() 
        mnist = mnist.to(device)

        # Train step
        d_real_loss, d_fake_loss = train_discriminator(svhn, mnist)
        g_loss = train_generator(svhn, mnist)
        
        # print the log info
        if (step+1) % 200 == 0:
            print('Step [%d/%d], d_real_loss: %.4f, '
                  'd_fake_loss: %.4f, g_loss: %.4f' 
                  %(step+1, train_iters, d_real_loss.item(), d_fake_loss.item(), g_loss.item()))

        # save the sampled images for visual inspection
        if (step+1) % 1000 == 0:
            s2m.eval()
            m2s.eval()
            fake_svhn = m2s(fixed_mnist)
            fake_mnist = s2m(fixed_svhn)

            vis_m2s = make_grid(fixed_mnist, fake_svhn)
            path = os.path.join('samples', 'sample-%d-m-s.png' %(step+1))
            #print(vis_m2s)
            #imageio.imwrite(path, vis_m2s)
            vis_m2s.save(path)
            print ('saved %s' %path)

            vis_s2m = make_grid(fixed_svhn, fake_mnist)
            path = os.path.join('samples', 'sample-%d-s-m.png' %(step+1))
            #imageio.imwrite(path, vis_s2m)
            vis_s2m.save(path)
            print ('saved %s' %path)

    return fake_mnist, fake_svhn, vis_m2s, vis_s2m

# %%
def make_grid(sources, targets, k=10):
    if sources.shape[1] == 1:
        sources = torch.repeat_interleave(sources, 3, 1)
    if targets.shape[1] == 1:
        targets = torch.repeat_interleave(targets, 3, 1)
    b,_,h,w = sources.shape
    img = torch.cat([sources.unsqueeze(1), targets.unsqueeze(1)], axis=1)
    img = img.view(2*b,3,h,w)
    img = torchvision.utils.make_grid(img).cpu().detach()#.numpy().transpose(1,2,0)
    return transforms.ToPILImage()(img).convert("RGB")

# %%
fake_mnist, fake_svhn, vis_m2s, vis_s2m = train(svhn_loader, mnist_loader, 30000)
# Out:
# Step [200/30000], d_real_loss: 0.1564, d_fake_loss: 0.2681, g_loss: 1.3876
# Step [400/30000], d_real_loss: 0.4615, d_fake_loss: 0.1557, g_loss: 0.8274
# Step [600/30000], d_real_loss: 0.4582, d_fake_loss: 0.1640, g_loss: 0.8398
# Step [800/30000], d_real_loss: 0.1872, d_fake_loss: 0.4933, g_loss: 1.3904
# Step [1000/30000], d_real_loss: 0.1877, d_fake_loss: 0.4687, g_loss: 1.3690
# saved samples/sample-1000-m-s.png
# saved samples/sample-1000-s-m.png
# Step [1200/30000], d_real_loss: 0.2626, d_fake_loss: 0.3248, g_loss: 1.1232
# Step [1400/30000], d_real_loss: 0.3864, d_fake_loss: 0.2631, g_loss: 0.8649
# Step [1600/30000], d_real_loss: 0.3046, d_fake_loss: 0.2994, g_loss: 1.2862
# Step [1800/30000], d_real_loss: 0.6054, d_fake_loss: 0.1626, g_loss: 0.6908
# Step [2000/30000], d_real_loss: 0.3802, d_fake_loss: 0.3370, g_loss: 1.2157
# saved samples/sample-2000-m-s.png
# saved samples/sample-2000-s-m.png
# Step [2200/30000], d_real_loss: 0.3208, d_fake_loss: 0.2475, g_loss: 1.0955
# Step [2400/30000], d_real_loss: 0.2760, d_fake_loss: 0.2790, g_loss: 1.1494
# Step [2600/30000], d_real_loss: 0.3010, d_fake_loss: 0.2241, g_loss: 1.0384
# Step [2800/30000], d_real_loss: 0.2926, d_fake_loss: 0.2870, g_loss: 1.1504
# Step [3000/30000], d_real_loss: 0.2897, d_fake_loss: 0.2727, g_loss: 1.1241
# saved samples/sample-3000-m-s.png
# saved samples/sample-3000-s-m.png
# Step [3200/30000], d_real_loss: 0.2676, d_fake_loss: 0.2753, g_loss: 1.3839
# Step [3400/30000], d_real_loss: 0.3711, d_fake_loss: 0.2916, g_loss: 1.2997
# Step [3600/30000], d_real_loss: 0.2013, d_fake_loss: 0.3007, g_loss: 1.3299
# Step [3800/30000], d_real_loss: 0.2800, d_fake_loss: 0.2754, g_loss: 1.2398
# Step [4000/30000], d_real_loss: 0.3556, d_fake_loss: 0.1905, g_loss: 1.1460
# saved samples/sample-4000-m-s.png
# saved samples/sample-4000-s-m.png
# Step [4200/30000], d_real_loss: 0.3025, d_fake_loss: 0.1635, g_loss: 1.3051
# Step [4400/30000], d_real_loss: 0.2373, d_fake_loss: 0.2354, g_loss: 1.4029
# Step [4600/30000], d_real_loss: 0.2979, d_fake_loss: 0.1623, g_loss: 1.0184
# Step [4800/30000], d_real_loss: 0.2994, d_fake_loss: 0.2357, g_loss: 1.3338
# Step [5000/30000], d_real_loss: 0.2950, d_fake_loss: 0.2093, g_loss: 1.2136
# saved samples/sample-5000-m-s.png
# saved samples/sample-5000-s-m.png
# Step [5200/30000], d_real_loss: 0.2493, d_fake_loss: 0.2254, g_loss: 1.2725
# Step [5400/30000], d_real_loss: 0.3633, d_fake_loss: 0.1054, g_loss: 1.1900
# Step [5600/30000], d_real_loss: 0.2239, d_fake_loss: 0.2288, g_loss: 1.4393
# Step [5800/30000], d_real_loss: 0.2730, d_fake_loss: 0.1723, g_loss: 1.3552
# Step [6000/30000], d_real_loss: 0.1847, d_fake_loss: 0.2320, g_loss: 1.4319
# saved samples/sample-6000-m-s.png
# saved samples/sample-6000-s-m.png
# Step [6200/30000], d_real_loss: 0.2324, d_fake_loss: 0.2049, g_loss: 1.3854
# Step [6400/30000], d_real_loss: 0.2788, d_fake_loss: 0.1466, g_loss: 1.3812
# Step [6600/30000], d_real_loss: 0.2425, d_fake_loss: 0.1496, g_loss: 1.3936
# Step [6800/30000], d_real_loss: 0.1467, d_fake_loss: 0.3168, g_loss: 1.7159
# Step [7000/30000], d_real_loss: 0.2873, d_fake_loss: 0.1759, g_loss: 1.2526
# saved samples/sample-7000-m-s.png
# saved samples/sample-7000-s-m.png
# Step [7200/30000], d_real_loss: 0.2004, d_fake_loss: 0.1589, g_loss: 1.4436
# Step [7400/30000], d_real_loss: 0.2388, d_fake_loss: 0.1840, g_loss: 1.6086
# Step [7600/30000], d_real_loss: 0.2086, d_fake_loss: 0.2000, g_loss: 1.5337
# Step [7800/30000], d_real_loss: 0.2527, d_fake_loss: 0.1969, g_loss: 1.3906
# Step [8000/30000], d_real_loss: 0.1464, d_fake_loss: 0.2140, g_loss: 1.6403
# saved samples/sample-8000-m-s.png
# saved samples/sample-8000-s-m.png
# Step [8200/30000], d_real_loss: 0.2225, d_fake_loss: 0.2239, g_loss: 1.8021
# Step [8400/30000], d_real_loss: 0.1872, d_fake_loss: 0.2966, g_loss: 1.6965
# Step [8600/30000], d_real_loss: 0.3116, d_fake_loss: 0.0779, g_loss: 1.4543
# Step [8800/30000], d_real_loss: 0.1595, d_fake_loss: 0.1901, g_loss: 1.6813
# Step [9000/30000], d_real_loss: 0.1770, d_fake_loss: 0.1731, g_loss: 1.5642
# saved samples/sample-9000-m-s.png
# saved samples/sample-9000-s-m.png
# Step [9200/30000], d_real_loss: 0.1958, d_fake_loss: 0.1763, g_loss: 1.5044
# Step [9400/30000], d_real_loss: 0.2156, d_fake_loss: 0.1496, g_loss: 1.5146
# Step [9600/30000], d_real_loss: 0.2819, d_fake_loss: 0.1809, g_loss: 1.4162
# Step [9800/30000], d_real_loss: 0.2505, d_fake_loss: 0.1626, g_loss: 1.5711
# Step [10000/30000], d_real_loss: 0.3001, d_fake_loss: 0.0853, g_loss: 1.3609
# saved samples/sample-10000-m-s.png
# saved samples/sample-10000-s-m.png
# Step [10200/30000], d_real_loss: 0.1996, d_fake_loss: 0.1726, g_loss: 1.7238
# Step [10400/30000], d_real_loss: 0.2269, d_fake_loss: 0.1093, g_loss: 1.6484
# Step [10600/30000], d_real_loss: 0.1392, d_fake_loss: 0.1584, g_loss: 1.7609
# Step [10800/30000], d_real_loss: 0.1943, d_fake_loss: 0.1494, g_loss: 1.5209
# Step [11000/30000], d_real_loss: 0.2425, d_fake_loss: 0.1341, g_loss: 1.5730
# saved samples/sample-11000-m-s.png
# saved samples/sample-11000-s-m.png
# Step [11200/30000], d_real_loss: 0.2333, d_fake_loss: 0.1900, g_loss: 1.4978
# Step [11400/30000], d_real_loss: 0.2104, d_fake_loss: 0.1331, g_loss: 1.4673
# Step [11600/30000], d_real_loss: 0.2826, d_fake_loss: 0.0987, g_loss: 1.5897
# Step [11800/30000], d_real_loss: 0.1880, d_fake_loss: 0.1062, g_loss: 1.6228
# Step [12000/30000], d_real_loss: 0.1591, d_fake_loss: 0.1751, g_loss: 1.6373
# saved samples/sample-12000-m-s.png
# saved samples/sample-12000-s-m.png
# Step [12200/30000], d_real_loss: 0.2383, d_fake_loss: 0.2286, g_loss: 1.2798
# Step [12400/30000], d_real_loss: 0.2721, d_fake_loss: 0.0945, g_loss: 1.4173
# Step [12600/30000], d_real_loss: 0.2011, d_fake_loss: 0.1833, g_loss: 1.4818
# Step [12800/30000], d_real_loss: 0.2124, d_fake_loss: 0.1176, g_loss: 1.4697
# Step [13000/30000], d_real_loss: 0.2390, d_fake_loss: 0.1436, g_loss: 1.6058
# saved samples/sample-13000-m-s.png
# saved samples/sample-13000-s-m.png
# Step [13200/30000], d_real_loss: 0.1932, d_fake_loss: 0.0967, g_loss: 1.6744
# Step [13400/30000], d_real_loss: 0.1658, d_fake_loss: 0.1518, g_loss: 1.7228
# Step [13600/30000], d_real_loss: 0.2345, d_fake_loss: 0.1067, g_loss: 1.6700
# Step [13800/30000], d_real_loss: 0.2859, d_fake_loss: 0.0776, g_loss: 1.3003
# Step [14000/30000], d_real_loss: 0.1985, d_fake_loss: 0.1445, g_loss: 1.6015
# saved samples/sample-14000-m-s.png
# saved samples/sample-14000-s-m.png
# Step [14200/30000], d_real_loss: 0.1930, d_fake_loss: 0.1383, g_loss: 1.5830
# Step [14400/30000], d_real_loss: 0.2418, d_fake_loss: 0.0754, g_loss: 1.5510
# Step [14600/30000], d_real_loss: 0.1655, d_fake_loss: 0.1434, g_loss: 1.6897
# Step [14800/30000], d_real_loss: 0.1544, d_fake_loss: 0.0990, g_loss: 1.6624
# Step [15000/30000], d_real_loss: 0.1517, d_fake_loss: 0.1260, g_loss: 1.6613
# saved samples/sample-15000-m-s.png
# saved samples/sample-15000-s-m.png
# Step [15200/30000], d_real_loss: 0.2017, d_fake_loss: 0.1650, g_loss: 1.3886
# Step [15400/30000], d_real_loss: 0.2518, d_fake_loss: 0.0899, g_loss: 1.5039
# Step [15600/30000], d_real_loss: 0.1417, d_fake_loss: 0.1268, g_loss: 1.6159
# Step [15800/30000], d_real_loss: 0.1909, d_fake_loss: 0.1003, g_loss: 1.6692
# Step [16000/30000], d_real_loss: 0.1756, d_fake_loss: 0.1235, g_loss: 1.8071
# saved samples/sample-16000-m-s.png
# saved samples/sample-16000-s-m.png
# Step [16200/30000], d_real_loss: 0.1446, d_fake_loss: 0.1225, g_loss: 1.6942
# Step [16400/30000], d_real_loss: 0.1481, d_fake_loss: 0.1509, g_loss: 1.7089
# Step [16600/30000], d_real_loss: 0.1705, d_fake_loss: 0.1322, g_loss: 1.7970
# Step [16800/30000], d_real_loss: 0.1358, d_fake_loss: 0.2086, g_loss: 1.9542
# Step [17000/30000], d_real_loss: 0.2238, d_fake_loss: 0.1162, g_loss: 1.5622
# saved samples/sample-17000-m-s.png
# saved samples/sample-17000-s-m.png
# Step [17200/30000], d_real_loss: 0.1491, d_fake_loss: 0.1035, g_loss: 1.7114
# Step [17400/30000], d_real_loss: 0.1363, d_fake_loss: 0.1733, g_loss: 1.9650
# Step [17600/30000], d_real_loss: 0.2305, d_fake_loss: 0.0909, g_loss: 1.5073
# Step [17800/30000], d_real_loss: 0.1941, d_fake_loss: 0.1744, g_loss: 1.8665
# Step [18000/30000], d_real_loss: 0.1920, d_fake_loss: 0.0820, g_loss: 1.4628
# saved samples/sample-18000-m-s.png
# saved samples/sample-18000-s-m.png
# Step [18200/30000], d_real_loss: 0.1358, d_fake_loss: 0.1271, g_loss: 1.6756
# Step [18400/30000], d_real_loss: 0.1516, d_fake_loss: 0.1393, g_loss: 1.6847
# Step [18600/30000], d_real_loss: 0.1745, d_fake_loss: 0.1751, g_loss: 1.6836
# Step [18800/30000], d_real_loss: 0.1374, d_fake_loss: 0.1230, g_loss: 1.7351
# Step [19000/30000], d_real_loss: 0.1266, d_fake_loss: 0.1798, g_loss: 1.8390
# saved samples/sample-19000-m-s.png
# saved samples/sample-19000-s-m.png
# Step [19200/30000], d_real_loss: 0.1536, d_fake_loss: 0.1096, g_loss: 1.7605
# Step [19400/30000], d_real_loss: 0.1685, d_fake_loss: 0.0908, g_loss: 1.7432
# Step [19600/30000], d_real_loss: 0.2095, d_fake_loss: 0.1170, g_loss: 1.8145
# Step [19800/30000], d_real_loss: 0.1819, d_fake_loss: 0.1144, g_loss: 1.5607
# Step [20000/30000], d_real_loss: 0.1032, d_fake_loss: 0.1078, g_loss: 1.8161
# saved samples/sample-20000-m-s.png
# saved samples/sample-20000-s-m.png
# Step [20200/30000], d_real_loss: 0.1991, d_fake_loss: 0.0728, g_loss: 1.5646
# Step [20400/30000], d_real_loss: 0.1905, d_fake_loss: 0.0946, g_loss: 1.6691
# Step [20600/30000], d_real_loss: 0.1414, d_fake_loss: 0.0973, g_loss: 1.6989
# Step [20800/30000], d_real_loss: 0.1469, d_fake_loss: 0.0996, g_loss: 1.7424
# Step [21000/30000], d_real_loss: 0.1676, d_fake_loss: 0.1129, g_loss: 1.6355
# saved samples/sample-21000-m-s.png
# saved samples/sample-21000-s-m.png
# Step [21200/30000], d_real_loss: 0.1409, d_fake_loss: 0.1421, g_loss: 1.7891
# Step [21400/30000], d_real_loss: 0.1953, d_fake_loss: 0.0961, g_loss: 1.6615
# Step [21600/30000], d_real_loss: 0.1560, d_fake_loss: 0.1621, g_loss: 1.6267
# Step [21800/30000], d_real_loss: 0.1899, d_fake_loss: 0.0734, g_loss: 1.5986
# Step [22000/30000], d_real_loss: 0.1336, d_fake_loss: 0.1333, g_loss: 1.7695
# saved samples/sample-22000-m-s.png
# saved samples/sample-22000-s-m.png
# Step [22200/30000], d_real_loss: 0.1810, d_fake_loss: 0.0790, g_loss: 1.6770
# Step [22400/30000], d_real_loss: 0.2561, d_fake_loss: 0.0596, g_loss: 1.5500
# Step [22600/30000], d_real_loss: 0.1384, d_fake_loss: 0.1133, g_loss: 1.7091
# Step [22800/30000], d_real_loss: 0.1887, d_fake_loss: 0.0828, g_loss: 1.6959
# Step [23000/30000], d_real_loss: 0.1380, d_fake_loss: 0.1768, g_loss: 1.7721
# saved samples/sample-23000-m-s.png
# saved samples/sample-23000-s-m.png
# Step [23200/30000], d_real_loss: 0.1618, d_fake_loss: 0.1166, g_loss: 1.6791
# Step [23400/30000], d_real_loss: 0.1637, d_fake_loss: 0.1042, g_loss: 1.6923
# Step [23600/30000], d_real_loss: 0.1642, d_fake_loss: 0.0921, g_loss: 1.7708
# Step [23800/30000], d_real_loss: 0.2170, d_fake_loss: 0.1174, g_loss: 1.8998
# Step [24000/30000], d_real_loss: 0.1528, d_fake_loss: 0.1018, g_loss: 1.9164
# saved samples/sample-24000-m-s.png
# saved samples/sample-24000-s-m.png
# Step [24200/30000], d_real_loss: 0.1663, d_fake_loss: 0.0858, g_loss: 1.7606
# Step [24400/30000], d_real_loss: 0.1565, d_fake_loss: 0.0888, g_loss: 1.6893
# Step [24600/30000], d_real_loss: 0.0959, d_fake_loss: 0.1313, g_loss: 1.8736
# Step [24800/30000], d_real_loss: 0.1189, d_fake_loss: 0.1390, g_loss: 1.6559
# Step [25000/30000], d_real_loss: 0.1222, d_fake_loss: 0.1276, g_loss: 1.8962
# saved samples/sample-25000-m-s.png
# saved samples/sample-25000-s-m.png
# Step [25200/30000], d_real_loss: 0.1287, d_fake_loss: 0.0828, g_loss: 1.7663
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-0843116515dc> in <module>()
# ----> 1 fake_mnist, fake_svhn, vis_m2s, vis_s2m = train(svhn_loader, mnist_loader, 30000)
#
# <ipython-input-10-cc29c380c2db> in train(svhn_loader, mnist_loader, train_iters)
#      24         # Train step
#      25         d_real_loss, d_fake_loss = train_discriminator(svhn, mnist)
# ---> 26         g_loss = train_generator(svhn, mnist)
#      27
#      28         # print the log info
#
# <ipython-input-8-003060bd7d3b> in train_generator(svhn, mnist)
#      10     fake_svhn = m2s(mnist)
#      11     out = ds(fake_svhn)
# ---> 12     reconst_mnist = s2m(fake_svhn)
#      13
#      14     mnist_g_loss = torch.mean((out-1)**2) # MSE
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-5-5dbbc08b9503> in forward(self, x)
#      24         out = self.bn1(out)
#      25         out = F.leaky_relu(self.conv2(out))    # (-1, 128, 8, 8)
# ---> 26         out = self.bn2(out)
#      27         out = F.leaky_relu(self.conv3(out))    # (-1, 128, 8, 8)
#      28         out = self.bn3(out)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/batchnorm.py in forward(self, input)
#     111             # TODO: if statement only here to tell the jit to skip emitting this when it is None
#     112             if self.num_batches_tracked is not None:  # type: ignore
# --> 113                 self.num_batches_tracked = self.num_batches_tracked + 1  # type: ignore
#     114                 if self.momentum is None:  # use cumulative moving average
#     115                     exponential_average_factor = 1.0 / float(self.num_batches_tracked)
#
# KeyboardInterrupt:

# %%
svhn_iter = iter(svhn_loader)
mnist_iter = iter(mnist_loader)
iter_per_epoch = min(len(svhn_iter), len(mnist_iter))

# Select some random samples fir visual validation
fixed_svhn = svhn_iter.next()[0].to(device)
fixed_mnist = mnist_iter.next()[0].to(device)

s2m.eval()
m2s.eval()
fake_svhn = m2s(fixed_mnist)
fake_mnist = s2m(fixed_svhn)

mergedm2s = make_grid(fixed_mnist, fake_svhn)
mergeds2m = make_grid(fixed_svhn, fake_mnist)

# %%
plt.figure(figsize=(8*2,16*2))
plt.imshow(mergedm2s)

# %%
plt.figure(figsize=(8*2,16*2))
plt.imshow(mergeds2m)

# %% [markdown]
# As you can see, many samples from SVHN were translated to MNIST-style as "1". This is possibly because the generator could confuse the discriminator easily with that. This is called the mode collapse problem. In some cases, you just need to give weights to the different components of the generator's loss function (maybe more weight to the cycle consistency loss). Another possible solution is utilizing the labels as described [here](https://colab.research.google.com/drive/1lc_5r55HgTFnj4Bj0I6fGXtq4ufThlvf?usp=sharing).
